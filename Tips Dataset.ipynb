# %% [markdown]
# # Tips Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ### Bar Plot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with a size of 12x6 inches
plt.figure(figsize=(12, 6))

# Subplot 1: Seaborn barplot
plt.subplot(1, 2, 1)  
sns.barplot(x='sex', y='tip', data=tips)
plt.title("Sex vs Tips (Seaborn)")  

# Subplot 2: Matplotlib bar plot
plt.subplot(1, 2, 2)  
plt.bar(tips['sex'], tips['tip'])
plt.xlabel('Sex')
plt.ylabel('Tips')
plt.title('Sex vs Tips (Matplotlib)')  

plt.tight_layout() 
plt.show()

# %% [markdown]
# ### Countplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with a size of 12x6 inches
plt.figure(figsize=(12, 6))

# Subplot 1: Seaborn countplot
plt.subplot(1, 2, 1)  
sns.countplot(x='sex', data=tips)
plt.title("Sex vs Count (Seaborn)")  

# Subplot 2: Matplotlib countplot
#Matplotlib does not have a countplot function of its own so we plot the values counts
sex_counts = tips['sex'].value_counts()

plt.subplot(1, 2, 2)
plt.bar(sex_counts.index, sex_counts.values)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Sex vs Count (Matplotlib)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### BoxPlot

# %%
#seaborn
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#matplotlib
Days = ['Thur', 'Fri', 'Sat', 'Sun']
order_by_day = [tips[tips['day'] == day]['total_bill'].values for day in Days]

plt.figure(figsize=(8, 6))
plt.boxplot(order_by_day, labels=Days)
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Day vs Total Bill (Matplotlib)')
plt.show()

# %%
#Seaborn Horizontal 
sns.boxplot(data=tips,orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Matplotlib
plt.figure(figsize=(8, 6))
plt.boxplot(tips['total_bill'], vert=False)
plt.xlabel('Total Bill')
plt.title('Boxplot of Total Bill (Matplotlib)')
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
#Seaborn
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')
plt.title('Violin Plot of Total Bill Amount by Day')
# Out:
# Text(0.5, 1.0, 'Violin Plot of Total Bill Amount by Day')

# %%
#Matplotlib
# Group the data by 'day' and extract 'total_bill' values for each group
days = tips['day'].unique()
data_by_day = [tips[tips['day'] == day]['total_bill'].values for day in days]
plt.violinplot(data_by_day, showmedians=True)

plt.xticks(range(1, len(days) + 1), days)

# Set labels and title
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill Amount')
plt.title('Violin Plot of Total Bill Amount by Day')

# Show the plot
plt.show()

# %%
#Seaborn
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Matplotlib
# Group the data by 'day' and 'sex' and extract 'total_bill' values for each group
groups = tips.groupby(['day', 'sex'])
data_by_group = [group['total_bill'].values for _, group in groups]

plt.figure(figsize=(10, 6))
plt.violinplot(data_by_group, showmedians=True)

# Set x-axis labels
days = tips['day'].unique()
day_labels = [f'{day} ({sex})' for day in days for sex in tips['sex'].unique()]
plt.xticks(range(1, len(day_labels) + 1), day_labels, rotation=45)

# Set labels and title
plt.xlabel('Day of the Week (Sex)')
plt.ylabel('Total Bill Amount')
plt.title('Violin Plot of Total Bill Amount by Day and Sex')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distplot

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\ramit\AppData\Local\Temp\ipykernel_25984\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# C:\Users\ramit\AppData\Local\Temp\ipykernel_7872\1163654811.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.displot(tips['total_bill'],kde=True)

# %%
sns.displot(tips['total_bill'],kde=False) #kde=False gives only bins similar to a histogram

# %%
#Matplotlib
plt.figure(figsize=(8, 6))  #
plt.hist(tips['total_bill'], bins=20, edgecolor='black') 

# Set labels and title
plt.xlabel('Total Bill Amount')
plt.ylabel('Frequency')
plt.title('Histogram of Total Bill Amount')

# Show the plot
plt.show()

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(x="total_bill",y="tip",data=tips)

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,kind='reg') #regression line

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,hue='sex')

# %%
sns.jointplot(x="total_bill",y="tip",data=tips,hue='day')

# %%
df=pd.DataFrame(tips.groupby('sex')['tip'].sum())

# %%
df
# Out:
#            tip
# sex
# Male    485.07
# Female  246.51

# %%
df.reset_index()
# Out:
#       sex     tip
# 0    Male  485.07
# 1  Female  246.51

# %%
df
# Out:
#            tip
# sex
# Male    485.07
# Female  246.51

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.groupby('sex')['tip'].mean()
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
tips.groupby('sex')['tip'].median()
# Out:
# sex
# Male      3.00
# Female    2.75
# Name: tip, dtype: float64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1=pd.DataFrame(tips.groupby('tip')['total_bill'].sum())

# %%
df1
# Out:
#        total_bill
# tip
# 1.00        28.67
# 1.01        16.99
# 1.10        12.90
# 1.17        32.83
# 1.25        29.09
# ...           ...
# 6.70        34.30
# 6.73        48.27
# 7.58        39.42
# 9.00        48.33
# 10.00       50.81
#
# [123 rows x 1 columns]

# %%
df1.reset_index()
# Out:
#        tip  total_bill
# 0     1.00       28.67
# 1     1.01       16.99
# 2     1.10       12.90
# 3     1.17       32.83
# 4     1.25       29.09
# ..     ...         ...
# 118   6.70       34.30
# 119   6.73       48.27
# 120   7.58       39.42
# 121   9.00       48.33
# 122  10.00       50.81
#
# [123 rows x 2 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['tip'].max()
# Out:
# 10.0

# %%
tips['tip'].idxmax()
# Out:
# 170

# %%
tips.drop(tips['tip'].idxmax(),inplace=True)

# %%
tips.drop(tips['tip'].idxmax(),inplace=True)

# %%
tips.groupby('sex')['tip'].mean()
# Out:
# sex
# Male      3.006903
# Female    2.833448
# Name: tip, dtype: float64

# %%
sns.barplot(tips)
# Out:
# <Axes: >

# %%
sns.barplot(x='sex',y='tip',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.var)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(y="day",x="total_bill",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swarmplot

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# ### Rugplot

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(tips['tip'])
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>
